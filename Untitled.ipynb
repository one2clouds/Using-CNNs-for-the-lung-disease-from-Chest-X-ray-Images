# %%
# import cv2 
# import tensorflow as tf
# import imghdr 
# from matplotlib import pyplot as plt
# import numpy as np
# import os
# import glob
# import shutil

# %%
# source = r'C:\Users\Hp\OneDrive\Desktop\train\PNEUMONIA'
# destination1 = r'C:\Users\Hp\OneDrive\Desktop\train\Bacteria Nenomia'
# destination2 = r'C:\Users\Hp\OneDrive\Desktop\train\Virus Nenomia'

# # gather all files
# allfiles1 = glob.glob(os.path.join(source, '*_bacteria_*'), recursive=True)
# allfiles2 = glob.glob(os.path.join(source, '*_virus_*'), recursive=True)

 
# # iterate on all files to move them to destination folder
# for file_path in allfiles1:
#     dst_path = os.path.join(destination1, os.path.basename(file_path))
#     shutil.move(file_path, dst_path)
    
# for file_path in allfiles2:
#     dst_path = os.path.join(destination2, os.path.basename(file_path))
#     shutil.move(file_path, dst_path)

# %%
# bacteria_neumonia_dir = r"D:\GRIT FEAT AI HACKATHON DATASET\Bacteria Nenomia"
# covid_19_dir = r"D:\GRIT FEAT AI HACKATHON DATASET\COVID-19"
# normal_dir = r"D:\GRIT FEAT AI HACKATHON DATASET\NORMAL"
# tuberculosis_dir = r"D:\GRIT FEAT AI HACKATHON DATASET\Tuberculosis"
# virus_neumonia_dir = r"D:\GRIT FEAT AI HACKATHON DATASET\Virus Nenomia"

# %%
# bacteria_data = os.listdir(bacteria_neumonia_dir)
# covid_19_data = os.listdir(covid_19_dir)
# normal_data = os.listdir(normal_dir)
# tuberculosis_data = os.listdir(tuberculosis_dir)
# virus_neumonia_data = os.listdir(virus_neumonia_dir)

# %%
# import pandas as pd

# %%
# df0 = pd.DataFrame({
#     'data' : bacteria_data,
#     'label' : 0 #bactorial_neumonia   
# })
# df1 = pd.DataFrame({
#     'data' : covid_19_data,
#     'label' : 1 #covid19   
# })
# df2 = pd.DataFrame({
#     'data' : normal_data,
#     'label' : 2 #normal_data   
# })
# df3 = pd.DataFrame({
#     'data' : tuberculosis_data,
#     'label' : 3 #tuberculosis   
# })
# df4 = pd.DataFrame({
#     'data' : virus_neumonia_data,
#     'label' : 4 #virus neumonia
# })

# %%
# df0.value_counts()

# %%
# aa = pd.concat([df0,df1,df2,df3,df4],axis=0)
# aa

# %%
# aa = aa.sample(frac=1)
# aa.reset_index(drop=True,inplace=True)
# aa

# %% [markdown]
# # THIS IS PREPROCESSING DON'T RUN THIS

# %%
base_dir = r"D:\GRIT FEAT AI HACKATHON DATASET\train"

# %%
import matplotlib.image as img
import matplotlib.pyplot as plt
#plt.subplot(1,2,1)
x = plt.imshow(img.imread(r'D:\GRIT FEAT AI HACKATHON DATASET\train_\Bacteria Nenomia\person26_bacteria_131.jpeg'))

# %%
x.get_size()
# Out:
# (200, 300)

# %%
import cv2

# %% [markdown]
# RESIZING ALL IMAGES INTO SAME SIZE 300 X 200

# %%
dest_path = r'D:\GRIT FEAT AI HACKATHON DATASET\train\Bacteria Nenomia'
file_name = 'hello.jpg'

# %%
filepath = os.path.join(dest_path, file_name)
print(filepath)

# %%
print(f'{dest_path}\{file_name}')

# %%
def resize_myimage(file_name_and_its_path,dest_path):
    img = cv2.imread(file_name_and_its_path, cv2.IMREAD_UNCHANGED)
    width = 300
    height = 200
    dim = (width, height)
    # resize image
    try:
        resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
        file_name = os.path.basename(file_name_and_its_path)
        cv2.imwrite(f'{dest_path}\{file_name}', resized)
    except: pass
#     try: 
#         os.remove(imagePath)
#     except: pass

# %%
directory1 = r"D:\GRIT FEAT AI HACKATHON DATASET\test\Bacteria Nenomia"
directory2 = r"D:\GRIT FEAT AI HACKATHON DATASET\test\COVID-19"
directory3 = r"D:\GRIT FEAT AI HACKATHON DATASET\test\NORMAL"
directory4 = r"D:\GRIT FEAT AI HACKATHON DATASET\test\Tuberculosis"
directory5 = r"D:\GRIT FEAT AI HACKATHON DATASET\test\Virus Nenomia"

# %%
#FOR BACTERIA NEMONIA
dst_path = r'D:\GRIT FEAT AI HACKATHON DATASET\test_\Bacteria Nenomia'
for filename in os.listdir(directory1):
    filepath = os.path.join(directory1, filename)
    resize_myimage(filepath,dst_path)

# %%
#FOR COVID 19 
dst_path = r'D:\GRIT FEAT AI HACKATHON DATASET\test_\COVID-19'
for filename in os.listdir(directory2):
    filepath = os.path.join(directory2, filename)
    resize_myimage(filepath,dst_path)

# %%
#FOR NORMAL
dst_path = r'D:\GRIT FEAT AI HACKATHON DATASET\test_\NORMAL'
for filename in os.listdir(directory3):
    filepath = os.path.join(directory3, filename)
    resize_myimage(filepath,dst_path)

# %%
#FOR Tuberculosis
dst_path = r'D:\GRIT FEAT AI HACKATHON DATASET\test_\Tuberculosis'
for filename in os.listdir(directory4):
    filepath = os.path.join(directory4, filename)
    resize_myimage(filepath,dst_path)

# %%
#FOR Virus Nemoia
dst_path = r'D:\GRIT FEAT AI HACKATHON DATASET\test_\Virus Nenomia'
for filename in os.listdir(directory5):
    filepath = os.path.join(directory5, filename)
    resize_myimage(filepath,dst_path)

# %% [markdown]
# # START CODE AFTER THIS

# %%
import cv2 
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import os

# %%
base__train_dir = r"D:\GRIT FEAT AI HACKATHON DATASET\train_"
base_test_dir = r"D:\GRIT FEAT AI HACKATHON DATASET\test_"

# %%
image_length_size = 300
image_height_size = 200
batch_size = 32

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 40,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip  = True,
    fill_mode='nearest',
    validation_split = 0.1
)

# %%
train_generator = train_datagen.flow_from_directory(
    base__train_dir,
    target_size = (image_length_size,image_height_size),
    batch_size = batch_size,
    class_mode='sparse',
    subset = 'training',
    shuffle = True
)

# %%
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 40,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip =True,
    fill_mode = 'nearest',
    validation_split = 0.1
)

# %%
test_generator = test_datagen.flow_from_directory(
    base_test_dir,
    target_size = (image_length_size,image_height_size),
    batch_size = batch_size,
    class_mode='sparse',
    subset = 'validation',
    shuffle=True
)

# %%
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(image_length_size, image_height_size, 3)),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv2D(64, (3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv2D(32, (3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    #tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    #tf.keras.layers.MaxPooling2D(2,2),
    ## Flatten the results to feed into a DNN
    #tf.keras.layers.Flatten(), 
    ## 512 neuron hidden layer
    #tf.keras.layers.Dense(512, activation='relu'), 
    ## Only 48 output neuron.
    tf.keras.layers.Dense(5, activation='softmax')  
])

# %%
model.summary()

# %%
model.compile(optimizer= tf.keras.optimizers.RMSprop(learning_rate=1e-4),
              loss='sparse_categorical_crossentropy',
              metrics = ['accuracy'])

# %%
history = model.fit(
            train_generator,
            epochs=2,
            steps_per_epoch = 300,
    # 92k images = batch_size*steps
    #i.e steps = 10k/32 = 312
            #steps_per_epoch=total_train_batches//hvd.size(),
            validation_data=test_generator,
            verbose=1
            )

# %% [markdown]
# # USING TRANSFER LEARNING WITH VGG16

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
num_classes = 100
input_shape = (32, 32, 3)

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (50000, 32, 32, 3) - y_train shape: (50000, 1)
# x_test shape: (10000, 32, 32, 3) - y_test shape: (10000, 1)

# %%
x_train[0]
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [195, 205, 193],
#         [212, 224, 204],
#         [182, 194, 167]],
#
#        [[255, 255, 255],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [170, 176, 150],
#         [161, 168, 130],
#         [146, 154, 113]],
#
#        [[255, 255, 255],
#         [254, 254, 254],
#         [255, 255, 255],
#         ...,
#         [189, 199, 169],
#         [166, 178, 130],
#         [121, 133,  87]],
#
#        ...,
#
#        [[148, 185,  79],
#         [142, 182,  57],
#         [140, 179,  60],
#         ...,
#         [ 30,  17,   1],
#         [ 65,  62,  15],
#         [ 76,  77,  20]],
#
#        [[122, 157,  66],
#         [120, 155,  58],
#         [126, 160,  71],
#         ...,
#         [ 22,  16,   3],
#         [ 97, 112,  56],
#         [141, 161,  87]],
#
#        [[ 87, 122,  41],
#         [ 88, 122,  39],
#         [101, 134,  56],
# ...
